# %%
# 폴더 내 파일 목록 리스트로 가져오기
import os

path = './reporttxt/'
file_lists = os.listdir(path)

# %%
# 텍스트 파일 내용 리스트로 가져오기
total_list = []
for i in range(len(file_list)):
    f = open(f'{path+file_lists[i]}', 'r')
    data = f.read()
    data = eval(data)
    total_list.append(data)
f.close()
total_list

# %%
uni_gram_list_total = []
for lists in total_list:
    uni_gram_list = []
    for text_list in lists:
        uni_grams = [text_list[x:x+1] for x in range(0, len(text_list))]
        uni_gram_list.append(uni_grams)
    uni_gram_list_total.append(uni_gram_list)
uni_gram_list_total
# Out:
# [[[['국내'],
#    ['크레딧'],
#    ['워크아웃'],
#    ['워크아웃'],
#    ['파급효과'],
#    ['워크아웃'],
#    ['실물'],
#    ['금융'],
#    ['부문'],
#    ['충격']],
#   [['금융'],
#    ['부문'],
#    ['경우'],
#    ['워크아웃'],
#    ['원인'],
#    ['높'],
#    ['부채비율'],
#    ['PF'],
#    ['보증'],
#    ['자체'],
#    ['요인'],
#    ['점'],
#    ['제한적'],
#    ['사채발행'],
#    ['익스포저'],
#    ['부실'],
#    ['우려'],
#    ['기관'],
#    ['투자자'],
#    ['보수'],
#    ['투자'],
#    ['기조'],
#    ['점'],
#    ['고려'],
#    ['때'],
#    ['금번'],
#    ['이벤트'],
#    ['신용경색'],
#    ['가능성'],
#    ['제한']],
#   [['전반'],
#    ['건설'],
#    ['경기'],
#    ['부진'],
#    ['지속'],
#    ['가운데'],
#    ['시공'],
#    ['순위'],
#    ['이내'],
#    ['건설사'],
#    ['부실'],
#    ['확인'],
#    ['부동산'],
#    ['PF'],
#    ['관련'],
#    ['업종'],
#    ['기피'],
#    ['현상'],
#    ['보다'],
#    ['강화'],
#    ['전망']],
#   [['기준'], ['발행'], ['단기자금'], ['원화채권']],
#   [['이중'], ['기타법인'], ['사모펀드'], ['보유']],
#   [['전체'], ['익스포저'], ['직접'], ['여신'], ['PF'], ['사업장'], ['금융회사'], ['자산']],
# ...

# %%
bi_gram_list_total = []
for lists in total_list:
    bi_gram_list = []
    for text_list in lists:
        bi_grams = [text_list[x:x+2] for x in range(0, len(text_list))]
        bi_gram_list.append(bi_grams)
    bi_gram_list_total.append(bi_gram_list)
bi_gram_list_total
# Out:
# [[[['국내', '크레딧'],
#    ['크레딧', '워크아웃'],
#    ['워크아웃', '워크아웃'],
#    ['워크아웃', '파급효과'],
#    ['파급효과', '워크아웃'],
#    ['워크아웃', '실물'],
#    ['실물', '금융'],
#    ['금융', '부문'],
#    ['부문', '충격'],
#    ['충격']],
#   [['금융', '부문'],
#    ['부문', '경우'],
#    ['경우', '워크아웃'],
#    ['워크아웃', '원인'],
#    ['원인', '높'],
#    ['높', '부채비율'],
#    ['부채비율', 'PF'],
#    ['PF', '보증'],
#    ['보증', '자체'],
#    ['자체', '요인'],
#    ['요인', '점'],
#    ['점', '제한적'],
#    ['제한적', '사채발행'],
#    ['사채발행', '익스포저'],
#    ['익스포저', '부실'],
#    ['부실', '우려'],
#    ['우려', '기관'],
#    ['기관', '투자자'],
#    ['투자자', '보수'],
#    ['보수', '투자'],
#    ['투자', '기조'],
#    ['기조', '점'],
#    ['점', '고려'],
#    ['고려', '때'],
#    ['때', '금번'],
#    ['금번', '이벤트'],
#    ['이벤트', '신용경색'],
#    ['신용경색', '가능성'],
#    ['가능성', '제한'],
#    ['제한']],
#   [['전반', '건설'],
#    ['건설', '경기'],
#    ['경기', '부진'],
#    ['부진', '지속'],
#    ['지속', '가운데'],
#    ['가운데', '시공'],
#    ['시공', '순위'],
#    ['순위', '이내'],
#    ['이내', '건설사'],
#    ['건설사', '부실'],
# ...

# %%
tri_gram_list_total = []
for lists in total_list:
    tri_gram_list = []
    for text_list in lists:
        tri_grams = [text_list[x:x+3] for x in range(0, len(text_list))]
        tri_gram_list.append(tri_grams)
    tri_gram_list_total.append(tri_gram_list)
tri_gram_list_total
# Out:
# [[[['국내', '크레딧', '워크아웃'],
#    ['크레딧', '워크아웃', '워크아웃'],
#    ['워크아웃', '워크아웃', '파급효과'],
#    ['워크아웃', '파급효과', '워크아웃'],
#    ['파급효과', '워크아웃', '실물'],
#    ['워크아웃', '실물', '금융'],
#    ['실물', '금융', '부문'],
#    ['금융', '부문', '충격'],
#    ['부문', '충격'],
#    ['충격']],
#   [['금융', '부문', '경우'],
#    ['부문', '경우', '워크아웃'],
#    ['경우', '워크아웃', '원인'],
#    ['워크아웃', '원인', '높'],
#    ['원인', '높', '부채비율'],
#    ['높', '부채비율', 'PF'],
#    ['부채비율', 'PF', '보증'],
#    ['PF', '보증', '자체'],
#    ['보증', '자체', '요인'],
#    ['자체', '요인', '점'],
#    ['요인', '점', '제한적'],
#    ['점', '제한적', '사채발행'],
#    ['제한적', '사채발행', '익스포저'],
#    ['사채발행', '익스포저', '부실'],
#    ['익스포저', '부실', '우려'],
#    ['부실', '우려', '기관'],
#    ['우려', '기관', '투자자'],
#    ['기관', '투자자', '보수'],
#    ['투자자', '보수', '투자'],
#    ['보수', '투자', '기조'],
#    ['투자', '기조', '점'],
#    ['기조', '점', '고려'],
#    ['점', '고려', '때'],
#    ['고려', '때', '금번'],
#    ['때', '금번', '이벤트'],
#    ['금번', '이벤트', '신용경색'],
#    ['이벤트', '신용경색', '가능성'],
#    ['신용경색', '가능성', '제한'],
# ...

# %%
quad_gram_list_total = []
for lists in total_list:
    quad_gram_list = []
    for text_list in lists:
        quad_grams = [text_list[x:x+4] for x in range(0, len(text_list))]
        quad_gram_list.append(quad_grams)
    quad_gram_list_total.append(quad_gram_list)
quad_gram_list_total
# Out:
# [[[['국내', '크레딧', '워크아웃', '워크아웃'],
#    ['크레딧', '워크아웃', '워크아웃', '파급효과'],
#    ['워크아웃', '워크아웃', '파급효과', '워크아웃'],
#    ['워크아웃', '파급효과', '워크아웃', '실물'],
#    ['파급효과', '워크아웃', '실물', '금융'],
#    ['워크아웃', '실물', '금융', '부문'],
#    ['실물', '금융', '부문', '충격'],
#    ['금융', '부문', '충격'],
#    ['부문', '충격'],
#    ['충격']],
#   [['금융', '부문', '경우', '워크아웃'],
#    ['부문', '경우', '워크아웃', '원인'],
#    ['경우', '워크아웃', '원인', '높'],
#    ['워크아웃', '원인', '높', '부채비율'],
#    ['원인', '높', '부채비율', 'PF'],
#    ['높', '부채비율', 'PF', '보증'],
#    ['부채비율', 'PF', '보증', '자체'],
#    ['PF', '보증', '자체', '요인'],
#    ['보증', '자체', '요인', '점'],
#    ['자체', '요인', '점', '제한적'],
#    ['요인', '점', '제한적', '사채발행'],
#    ['점', '제한적', '사채발행', '익스포저'],
#    ['제한적', '사채발행', '익스포저', '부실'],
#    ['사채발행', '익스포저', '부실', '우려'],
#    ['익스포저', '부실', '우려', '기관'],
#    ['부실', '우려', '기관', '투자자'],
#    ['우려', '기관', '투자자', '보수'],
#    ['기관', '투자자', '보수', '투자'],
#    ['투자자', '보수', '투자', '기조'],
#    ['보수', '투자', '기조', '점'],
#    ['투자', '기조', '점', '고려'],
# ...

# %%
penta_gram_list_total = []
for lists in total_list:
    penta_gram_list = []
    for text_list in lists:
        penta_grams = [text_list[x:x+5] for x in range(0, len(text_list))]
        penta_gram_list.append(penta_grams)
    penta_gram_list_total.append(penta_gram_list)
penta_gram_list_total
# Out:
# [[[['국내', '크레딧', '워크아웃', '워크아웃', '파급효과'],
#    ['크레딧', '워크아웃', '워크아웃', '파급효과', '워크아웃'],
#    ['워크아웃', '워크아웃', '파급효과', '워크아웃', '실물'],
#    ['워크아웃', '파급효과', '워크아웃', '실물', '금융'],
#    ['파급효과', '워크아웃', '실물', '금융', '부문'],
#    ['워크아웃', '실물', '금융', '부문', '충격'],
#    ['실물', '금융', '부문', '충격'],
#    ['금융', '부문', '충격'],
#    ['부문', '충격'],
#    ['충격']],
#   [['금융', '부문', '경우', '워크아웃', '원인'],
#    ['부문', '경우', '워크아웃', '원인', '높'],
#    ['경우', '워크아웃', '원인', '높', '부채비율'],
#    ['워크아웃', '원인', '높', '부채비율', 'PF'],
#    ['원인', '높', '부채비율', 'PF', '보증'],
#    ['높', '부채비율', 'PF', '보증', '자체'],
#    ['부채비율', 'PF', '보증', '자체', '요인'],
#    ['PF', '보증', '자체', '요인', '점'],
#    ['보증', '자체', '요인', '점', '제한적'],
#    ['자체', '요인', '점', '제한적', '사채발행'],
#    ['요인', '점', '제한적', '사채발행', '익스포저'],
#    ['점', '제한적', '사채발행', '익스포저', '부실'],
#    ['제한적', '사채발행', '익스포저', '부실', '우려'],
#    ['사채발행', '익스포저', '부실', '우려', '기관'],
#    ['익스포저', '부실', '우려', '기관', '투자자'],
#    ['부실', '우려', '기관', '투자자', '보수'],
# ...

# %%
for i in range(1, 6):
    gram_list_total = []
    for lists in total_list:
        gram_list = []
        for text_list in lists:
            grams = [text_list[x:x+i] for x in range(0, len(text_list))]
            gram_list.append(grams)
        gram_list_total.append(gram_list)
    print(gram_list_total)
# Out:
# [[[['국내'], ['크레딧'], ['워크아웃'], ['워크아웃'], ['파급효과'], ['워크아웃'], ['실물'], ['금융'], ['부문'], ['충격']], [['금융'], ['부문'], ['경우'], ['워크아웃'], ['원인'], ['높'], ['부채비율'], ['PF'], ['보증'], ['자체'], ['요인'], ['점'], ['제한적'], ['사채발행'], ['익스포저'], ['부실'], ['우려'], ['기관'], ['투자자'], ['보수'], ['투자'], ['기조'], ['점'], ['고려'], ['때'], ['금번'], ['이벤트'], ['신용경색'], ['가능성'], ['제한']], [['전반'], ['건설'], ['경기'], ['부진'], ['지속'], ['가운데'], ['시공'], ['순위'], ['이내'], ['건설사'], ['부실'], ['확인'], ['부동산'], ['PF'], ['관련'], ['업종'], ['기피'], ['현상'], ['보다'], ['강화'], ['전망']], [['기준'], ['발행'], ['단기자금'], ['원화채권']], [['이중'], ['기타법인'], ['사모펀드'], ['보유']], [['전체'], ['익스포저'], ['직접'], ['여신'], ['PF'], ['사업장'], ['금융회사'], ['자산']], [['시장'], ['위축'], ['미미'], ['규모']], [['업종별'], ['증권사'], ['익스포저'], ['비중'], ['상대적'], ['높'], ['증권사'], ['경우'], ['PF'], ['우려'], ['고조'], ['유동화'], ['증권'], ['차환'], ['리스크'], ['부각'], ['가능성'], ['우려'], ['요인'], ['작용']], [['실물'], ['건설업'], ['전염'], ['단절'], ['정부'], ['지원책'], ['발'], ['빠르'], ['마련']], [['정부'], ['관련'], ['사업장'], ['분양'], ['계약자'], ['협력업체'], [
# ...
